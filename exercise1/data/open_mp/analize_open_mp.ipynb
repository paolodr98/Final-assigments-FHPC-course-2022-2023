# %% [markdown]
# ## Notebook for plots ex 1 - OpenMP scalability

# %%
# Import the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %% [markdown]
# ## Import the data

# %%
# -----------------STATIC----------------------------------------
path_THIN_static_1 = 'static/THIN_static_1.csv'
path_THIN_static_2 = 'static/THIN_static_2.csv'
path_THIN_static_3 = 'static/THIN_static_3.csv'
path_THIN_static_4 = 'static/THIN_static_4.csv'


THIN_static_1 = pd.read_csv(path_THIN_static_1)
THIN_static_2 = pd.read_csv(path_THIN_static_2)
THIN_static_3 = pd.read_csv(path_THIN_static_3)
THIN_static_4 = pd.read_csv(path_THIN_static_4)

# -----------------ORDERED----------------------------------------
path_THIN_ordered_1 = 'ordered/THIN_ordered_1.csv'
path_THIN_ordered_2 = 'ordered/THIN_ordered_2.csv'

THIN_ordered_1 = pd.read_csv(path_THIN_ordered_1)
THIN_ordered_2 = pd.read_csv(path_THIN_ordered_2)

# %% [markdown]
# ## Manipulate the data

# %%
# extract the first row for the x axis

n_threads = THIN_static_1['threads']
n_threads = sorted(n_threads.unique())

# %%
# MPI 1

THIN_static_1_means = THIN_static_1.groupby(['ksize', 'threads']).mean().to_numpy()
THIN_static_1_std = THIN_static_1.groupby(['ksize', 'threads']).std().to_numpy()

# MPI 2

THIN_static_2_means = THIN_static_2.groupby(['ksize', 'threads']).mean().to_numpy()
THIN_static_2_std = THIN_static_2.groupby(['ksize', 'threads']).std().to_numpy()

# MPI 3

THIN_static_3_means = THIN_static_3.groupby(['ksize', 'threads']).mean().to_numpy()
THIN_static_3_std = THIN_static_3.groupby(['ksize', 'threads']).std().to_numpy()

# MPI 4

THIN_static_4_means = THIN_static_4.groupby(['ksize', 'threads']).mean().to_numpy()
THIN_static_4_std = THIN_static_4.groupby(['ksize', 'threads']).std().to_numpy()


#--------------ORDERED---------------


# MPI 1

THIN_ord_1_means = THIN_ordered_1.groupby(['ksize', 'threads']).mean().to_numpy()
THIN_ord_1_std = THIN_ordered_1.groupby(['ksize', 'threads']).std().to_numpy()

# MPI 2

THIN_ord_2_means = THIN_ordered_2.groupby(['ksize', 'threads']).mean().to_numpy()
THIN_ord_2_std = THIN_ordered_2.groupby(['ksize', 'threads']).std().to_numpy()

# %%
# MPI 1

THIN_static_1_means_ksize_100 = THIN_static_1_means[0:7].reshape(7)
THIN_static_1_means_ksize_500 = THIN_static_1_means[7:14].reshape(7)
THIN_static_1_means_ksize_1000 = THIN_static_1_means[14:21].reshape(7)
THIN_static_1_means_ksize_5000 = THIN_static_1_means[21:28].reshape(7)
THIN_static_1_means_ksize_10000 = THIN_static_1_means[28:35].reshape(7)

THIN_static_1_std_ksize_100 = THIN_static_1_std[0:7].reshape(7)
THIN_static_1_std_ksize_500 = THIN_static_1_std[7:14].reshape(7)
THIN_static_1_std_ksize_1000 = THIN_static_1_std[14:21].reshape(7)
THIN_static_1_std_ksize_5000 = THIN_static_1_std[21:28].reshape(7)
THIN_static_1_std_ksize_10000 = THIN_static_1_std[28:35].reshape(7)

# MPI 2

THIN_static_2_means_ksize_100 = THIN_static_2_means[0:7].reshape(7)
THIN_static_2_means_ksize_500 = THIN_static_2_means[7:14].reshape(7)
THIN_static_2_means_ksize_1000 = THIN_static_2_means[14:21].reshape(7)
THIN_static_2_means_ksize_5000 = THIN_static_2_means[21:28].reshape(7)
THIN_static_2_means_ksize_10000 = THIN_static_2_means[28:35].reshape(7)

THIN_static_2_std_ksize_100 = THIN_static_2_std[0:7].reshape(7)
THIN_static_2_std_ksize_500 = THIN_static_2_std[7:14].reshape(7)
THIN_static_2_std_ksize_1000 = THIN_static_2_std[14:21].reshape(7)
THIN_static_2_std_ksize_5000 = THIN_static_2_std[21:28].reshape(7)
THIN_static_2_std_ksize_10000 = THIN_static_2_std[28:35].reshape(7)

# MPI 3

THIN_static_3_means_ksize_100 = THIN_static_3_means[0:7].reshape(7)
THIN_static_3_means_ksize_500 = THIN_static_3_means[7:14].reshape(7)
THIN_static_3_means_ksize_1000 = THIN_static_3_means[14:21].reshape(7)
THIN_static_3_means_ksize_5000 = THIN_static_3_means[21:28].reshape(7)
THIN_static_3_means_ksize_10000 = THIN_static_3_means[28:35].reshape(7)

THIN_static_3_std_ksize_100 = THIN_static_3_std[0:7].reshape(7)
THIN_static_3_std_ksize_500 = THIN_static_3_std[7:14].reshape(7)
THIN_static_3_std_ksize_1000 = THIN_static_3_std[14:21].reshape(7)
THIN_static_3_std_ksize_5000 = THIN_static_3_std[21:28].reshape(7)
THIN_static_3_std_ksize_10000 = THIN_static_3_std[28:35].reshape(7)


# MPI 4

THIN_static_4_means_ksize_100 = THIN_static_4_means[0:7].reshape(7)
THIN_static_4_means_ksize_500 = THIN_static_4_means[7:14].reshape(7)
THIN_static_4_means_ksize_1000 = THIN_static_4_means[14:21].reshape(7)
THIN_static_4_means_ksize_5000 = THIN_static_4_means[21:28].reshape(7)
THIN_static_4_means_ksize_10000 = THIN_static_4_means[28:35].reshape(7)

THIN_static_4_std_ksize_100 = THIN_static_4_std[0:7].reshape(7)
THIN_static_4_std_ksize_500 = THIN_static_4_std[7:14].reshape(7)
THIN_static_4_std_ksize_1000 = THIN_static_4_std[14:21].reshape(7)
THIN_static_4_std_ksize_5000 = THIN_static_4_std[21:28].reshape(7)
THIN_static_4_std_ksize_10000 = THIN_static_4_std[28:35].reshape(7)


#--------------ORDERED---------------


# MPI 1

THIN_ord_1_means_ksize_100 = THIN_ord_1_means[0:7].reshape(7)
THIN_ord_1_means_ksize_500 = THIN_ord_1_means[7:14].reshape(7)
THIN_ord_1_means_ksize_1000 = THIN_ord_1_means[14:21].reshape(7)
THIN_ord_1_means_ksize_5000 = THIN_ord_1_means[21:28].reshape(7)
THIN_ord_1_means_ksize_10000 = THIN_ord_1_means[28:35].reshape(7)

THIN_ord_1_std_ksize_100 = THIN_ord_1_std[0:7].reshape(7)
THIN_ord_1_std_ksize_500 = THIN_ord_1_std[7:14].reshape(7)
THIN_ord_1_std_ksize_1000 = THIN_ord_1_std[14:21].reshape(7)
THIN_ord_1_std_ksize_5000 = THIN_ord_1_std[21:28].reshape(7)
THIN_ord_1_std_ksize_10000 = THIN_ord_1_std[28:35].reshape(7)

# MPI 2

THIN_ord_2_means_ksize_100 = THIN_ord_2_means[0:7].reshape(7)
THIN_ord_2_means_ksize_500 = THIN_ord_2_means[7:14].reshape(7)
THIN_ord_2_means_ksize_1000 = THIN_ord_2_means[14:21].reshape(7)

THIN_ord_2_std_ksize_100 = THIN_ord_2_std[0:7].reshape(7)
THIN_ord_2_std_ksize_500 = THIN_ord_2_std[7:14].reshape(7)
THIN_ord_2_std_ksize_1000 = THIN_ord_2_std[14:21].reshape(7)

# %% [markdown]
# ## Plot

# %% [markdown]
# ### 1 MPI - static

# %%
fig = plt.figure(figsize=(10, 8))  # Set figure size (width=10, height=8)
ax = fig.add_subplot(111)  # Create the main plot in the entire figure

ax.plot(n_threads, THIN_static_1_means_ksize_1000, label = 'k = 1000', color = 'blue')
ax.plot(n_threads, THIN_static_1_means_ksize_5000, label = 'k = 5000', color = 'orange')
ax.plot(n_threads, THIN_static_1_means_ksize_10000, label = 'k = 10000', color = 'black')


ax.fill_between(n_threads, THIN_static_1_means_ksize_1000 - THIN_static_1_std_ksize_1000, THIN_static_1_means_ksize_1000 - THIN_static_1_std_ksize_1000, alpha=0.2, color = 'blue')
ax.fill_between(n_threads, THIN_static_1_means_ksize_5000 - THIN_static_1_std_ksize_5000, THIN_static_1_means_ksize_5000 - THIN_static_1_std_ksize_5000, alpha=0.2, color = 'orange')
ax.fill_between(n_threads, THIN_static_1_means_ksize_10000 - THIN_static_1_std_ksize_10000, THIN_static_1_means_ksize_10000 - THIN_static_1_std_ksize_10000, alpha=0.2, color = 'black')

ax.set_xlabel('Number of Threads', fontsize = 16)
ax.set_ylabel('Time', fontsize = 16)
ax.set_title('OpenMP scalability, Static, 1 MPI task ', fontsize = 18)

ax.legend(loc='upper center')

ax.grid()

# Define the inset plot location and size
# The arguments to 'inset_axes' are [left, bottom, width, height] as a fraction of the main plot
inset_ax = fig.add_axes([0.65, 0.6, 0.25, 0.25])  # Positioning inset at upper-right corner

# Create the inset plot
inset_ax.plot(n_threads, THIN_static_1_means_ksize_100, label = 'k = 100', color = 'red')
inset_ax.plot(n_threads, THIN_static_1_means_ksize_500, label = 'k = 500', color = 'green')
inset_ax.plot(n_threads, THIN_static_1_means_ksize_1000, label = 'k = 1000', color = 'blue')

inset_ax.fill_between(n_threads, THIN_static_1_means_ksize_100 - THIN_static_1_std_ksize_100, THIN_static_1_means_ksize_100 + THIN_static_1_std_ksize_100, alpha=0.2,  color = 'red')
inset_ax.fill_between(n_threads, THIN_static_1_means_ksize_500 - THIN_static_1_std_ksize_500,  THIN_static_1_means_ksize_500 + THIN_static_1_std_ksize_500, alpha=0.2, color = 'green')
inset_ax.fill_between(n_threads, THIN_static_1_means_ksize_1000 - THIN_static_1_std_ksize_1000, THIN_static_1_means_ksize_1000 - THIN_static_1_std_ksize_1000, alpha=0.2, color = 'blue')


inset_ax.set_ylabel('Time')
inset_ax.set_xlabel('N Threads')
inset_ax.set_title('Time vs N Thread')

inset_ax.legend(fontsize=10)
inset_ax.grid()

# Show the plot with the inset

plt.show()

# %% [markdown]
# ### 2 MPI - static

# %%
fig = plt.figure(figsize=(10, 8))  # Set figure size (width=10, height=8)
ax = fig.add_subplot(111)  # Create the main plot in the entire figure

ax.plot(n_threads, THIN_static_2_means_ksize_1000, label = 'k = 1000', color = 'blue')
ax.plot(n_threads, THIN_static_2_means_ksize_5000, label = 'k = 5000', color = 'orange')
ax.plot(n_threads, THIN_static_2_means_ksize_10000, label = 'k = 10000', color = 'black')


ax.fill_between(n_threads, THIN_static_2_means_ksize_1000 - THIN_static_2_std_ksize_1000, THIN_static_2_means_ksize_1000 - THIN_static_2_std_ksize_1000, alpha=0.2, color = 'blue')
ax.fill_between(n_threads, THIN_static_2_means_ksize_5000 - THIN_static_2_std_ksize_5000, THIN_static_2_means_ksize_5000 - THIN_static_2_std_ksize_5000, alpha=0.2, color = 'orange')
ax.fill_between(n_threads, THIN_static_2_means_ksize_10000 - THIN_static_2_std_ksize_10000, THIN_static_2_means_ksize_10000 - THIN_static_2_std_ksize_10000, alpha=0.2, color = 'black')

ax.set_xlabel('Number of Threads', fontsize = 16)
ax.set_ylabel('Time', fontsize = 16)
ax.set_title('OpenMP scalability, Static, 2 MPI task ', fontsize = 18)

ax.legend(loc='upper center')

ax.grid()

# Define the inset plot location and size
# The arguments to 'inset_axes' are [left, bottom, width, height] as a fraction of the main plot
inset_ax = fig.add_axes([0.65, 0.63, 0.25, 0.25])  # Positioning inset at upper-right corner

# Create the inset plot
inset_ax.plot(n_threads, THIN_static_2_means_ksize_100, label = 'k = 100', color = 'red')
inset_ax.plot(n_threads, THIN_static_2_means_ksize_500, label = 'k = 500', color = 'green')
inset_ax.plot(n_threads, THIN_static_2_means_ksize_1000, label = 'k = 1000', color = 'blue')

inset_ax.fill_between(n_threads, THIN_static_2_means_ksize_100 - THIN_static_2_std_ksize_100, THIN_static_2_means_ksize_100 + THIN_static_2_std_ksize_100, alpha=0.2,  color = 'red')
inset_ax.fill_between(n_threads, THIN_static_2_means_ksize_500 - THIN_static_2_std_ksize_500,  THIN_static_2_means_ksize_500 + THIN_static_2_std_ksize_500, alpha=0.2, color = 'green')
inset_ax.fill_between(n_threads, THIN_static_2_means_ksize_1000 - THIN_static_2_std_ksize_1000, THIN_static_2_means_ksize_1000 - THIN_static_2_std_ksize_1000, alpha=0.2, color = 'blue')


inset_ax.set_ylabel('Time')
inset_ax.set_xlabel('N Threads')


inset_ax.legend(fontsize=10)
inset_ax.grid()

# Show the plot with the inset

plt.show()

# %% [markdown]
# ### 3 MPI - static

# %%
fig = plt.figure(figsize=(10, 8))  # Set figure size (width=10, height=8)
ax = fig.add_subplot(111)  # Create the main plot in the entire figure

ax.plot(n_threads, THIN_static_3_means_ksize_1000, label = 'k = 1000', color = 'blue')
ax.plot(n_threads, THIN_static_3_means_ksize_5000, label = 'k = 5000', color = 'orange')
ax.plot(n_threads, THIN_static_3_means_ksize_10000, label = 'k = 10000', color = 'black')


ax.fill_between(n_threads, THIN_static_3_means_ksize_1000 - THIN_static_3_std_ksize_1000, THIN_static_3_means_ksize_1000 - THIN_static_3_std_ksize_1000, alpha=0.2, color = 'blue')
ax.fill_between(n_threads, THIN_static_3_means_ksize_5000 - THIN_static_3_std_ksize_5000, THIN_static_3_means_ksize_5000 - THIN_static_3_std_ksize_5000, alpha=0.2, color = 'orange')
ax.fill_between(n_threads, THIN_static_3_means_ksize_10000 - THIN_static_3_std_ksize_10000, THIN_static_3_means_ksize_10000 - THIN_static_3_std_ksize_10000, alpha=0.2, color = 'black')

ax.set_xlabel('Number of Threads', fontsize = 16)
ax.set_ylabel('Time', fontsize = 16)
ax.set_title('OpenMP scalability, Static, 3 MPI task ', fontsize = 18)

ax.legend(loc='upper center')

ax.grid()

# Define the inset plot location and size
# The arguments to 'inset_axes' are [left, bottom, width, height] as a fraction of the main plot
inset_ax = fig.add_axes([0.65, 0.63, 0.25, 0.25])  # Positioning inset at upper-right corner

# Create the inset plot
inset_ax.plot(n_threads, THIN_static_3_means_ksize_100, label = 'k = 100', color = 'red')
inset_ax.plot(n_threads, THIN_static_3_means_ksize_500, label = 'k = 500', color = 'green')
inset_ax.plot(n_threads, THIN_static_3_means_ksize_1000, label = 'k = 1000', color = 'blue')

inset_ax.fill_between(n_threads, THIN_static_3_means_ksize_100 - THIN_static_3_std_ksize_100, THIN_static_3_means_ksize_100 + THIN_static_3_std_ksize_100, alpha=0.2,  color = 'red')
inset_ax.fill_between(n_threads, THIN_static_3_means_ksize_500 - THIN_static_3_std_ksize_500,  THIN_static_3_means_ksize_500 + THIN_static_3_std_ksize_500, alpha=0.2, color = 'green')
inset_ax.fill_between(n_threads, THIN_static_3_means_ksize_1000 - THIN_static_3_std_ksize_1000, THIN_static_3_means_ksize_1000 - THIN_static_3_std_ksize_1000, alpha=0.2, color = 'blue')


inset_ax.set_ylabel('Time')
inset_ax.set_xlabel('N Threads')


inset_ax.legend(fontsize=10)
inset_ax.grid()

# Show the plot with the inset

plt.show()

# %% [markdown]
# ### 4 MPI - static

# %%
fig = plt.figure(figsize=(10, 8))  # Set figure size (width=10, height=8)
ax = fig.add_subplot(111)  # Create the main plot in the entire figure

ax.plot(n_threads, THIN_static_4_means_ksize_1000, label = 'k = 1000', color = 'blue')
ax.plot(n_threads, THIN_static_4_means_ksize_5000, label = 'k = 5000', color = 'orange')
ax.plot(n_threads, THIN_static_4_means_ksize_10000, label = 'k = 10000', color = 'black')


ax.fill_between(n_threads, THIN_static_4_means_ksize_1000 - THIN_static_4_std_ksize_1000, THIN_static_4_means_ksize_1000 - THIN_static_4_std_ksize_1000, alpha=0.2, color = 'blue')
ax.fill_between(n_threads, THIN_static_4_means_ksize_5000 - THIN_static_4_std_ksize_5000, THIN_static_4_means_ksize_5000 - THIN_static_4_std_ksize_5000, alpha=0.2, color = 'orange')
ax.fill_between(n_threads, THIN_static_4_means_ksize_10000 - THIN_static_4_std_ksize_10000, THIN_static_4_means_ksize_10000 - THIN_static_4_std_ksize_10000, alpha=0.2, color = 'black')

ax.set_xlabel('Number of Threads', fontsize = 16)
ax.set_ylabel('Time', fontsize = 16)
ax.set_title('OpenMP scalability, Static, 4 MPI task ', fontsize = 18)

ax.legend(loc='upper center')

ax.grid()

# Define the inset plot location and size
# The arguments to 'inset_axes' are [left, bottom, width, height] as a fraction of the main plot
inset_ax = fig.add_axes([0.65, 0.63, 0.25, 0.25])  # Positioning inset at upper-right corner

# Create the inset plot
inset_ax.plot(n_threads, THIN_static_4_means_ksize_100, label = 'k = 100', color = 'red')
inset_ax.plot(n_threads, THIN_static_4_means_ksize_500, label = 'k = 500', color = 'green')
inset_ax.plot(n_threads, THIN_static_4_means_ksize_1000, label = 'k = 1000', color = 'blue')

inset_ax.fill_between(n_threads, THIN_static_4_means_ksize_100 - THIN_static_4_std_ksize_100, THIN_static_4_means_ksize_100 + THIN_static_4_std_ksize_100, alpha=0.2,  color = 'red')
inset_ax.fill_between(n_threads, THIN_static_4_means_ksize_500 - THIN_static_4_std_ksize_500,  THIN_static_4_means_ksize_500 + THIN_static_4_std_ksize_500, alpha=0.2, color = 'green')
inset_ax.fill_between(n_threads, THIN_static_4_means_ksize_1000 - THIN_static_4_std_ksize_1000, THIN_static_4_means_ksize_1000 - THIN_static_4_std_ksize_1000, alpha=0.2, color = 'blue')


inset_ax.set_ylabel('Time')
inset_ax.set_xlabel('N Threads')

inset_ax.legend(fontsize=10)
inset_ax.grid()

# Show the plot with the inset

plt.show()

# %% [markdown]
# ### 1 MPI - ordered

# %%
fig = plt.figure(figsize=(10, 8))  # Set figure size (width=10, height=8)
ax = fig.add_subplot(111)  # Create the main plot in the entire figure

ax.plot(n_threads, THIN_ord_1_means_ksize_1000, label = 'k = 1000', color = 'blue')
ax.plot(n_threads, THIN_ord_1_means_ksize_5000, label = 'k = 5000', color = 'orange')
ax.plot(n_threads, THIN_ord_1_means_ksize_10000, label = 'k = 10000', color = 'black')


ax.fill_between(n_threads, THIN_ord_1_means_ksize_1000 - THIN_ord_1_std_ksize_1000, THIN_ord_1_means_ksize_1000 - THIN_ord_1_std_ksize_1000, alpha=0.2, color = 'blue')
ax.fill_between(n_threads, THIN_ord_1_means_ksize_5000 - THIN_ord_1_std_ksize_5000, THIN_ord_1_means_ksize_5000 - THIN_ord_1_std_ksize_5000, alpha=0.2, color = 'orange')
ax.fill_between(n_threads, THIN_ord_1_means_ksize_10000 - THIN_ord_1_std_ksize_10000, THIN_ord_1_means_ksize_10000 - THIN_ord_1_std_ksize_10000, alpha=0.2, color = 'black')

ax.set_xlabel('Number of Threads', fontsize = 16)
ax.set_ylabel('Time', fontsize = 16)
ax.set_title('OpenMP scalability, Ordered, 1 MPI task ', fontsize = 18)

ax.legend(loc='upper center')

ax.grid()

# Define the inset plot location and size
# The arguments to 'inset_axes' are [left, bottom, width, height] as a fraction of the main plot
inset_ax = fig.add_axes([0.65, 0.57, 0.25, 0.25])  # Positioning inset at upper-right corner

# Create the inset plot
inset_ax.plot(n_threads, THIN_ord_1_means_ksize_100, label = 'k = 100', color = 'red')
inset_ax.plot(n_threads, THIN_ord_1_means_ksize_500, label = 'k = 500', color = 'green')
inset_ax.plot(n_threads, THIN_ord_1_means_ksize_1000, label = 'k = 1000', color = 'blue')

inset_ax.fill_between(n_threads, THIN_ord_1_means_ksize_100 - THIN_ord_1_std_ksize_100, THIN_ord_1_means_ksize_100 + THIN_ord_1_std_ksize_100, alpha=0.2,  color = 'red')
inset_ax.fill_between(n_threads, THIN_ord_1_means_ksize_500 - THIN_ord_1_std_ksize_500,  THIN_ord_1_means_ksize_500 + THIN_ord_1_std_ksize_500, alpha=0.2, color = 'green')
inset_ax.fill_between(n_threads, THIN_ord_1_means_ksize_1000 - THIN_ord_1_std_ksize_1000, THIN_ord_1_means_ksize_1000 - THIN_ord_1_std_ksize_1000, alpha=0.2, color = 'blue')


inset_ax.set_ylabel('Time')
inset_ax.set_xlabel('N Threads')


inset_ax.legend(fontsize=10)
inset_ax.grid()

# Show the plot with the inset

plt.show()

# %% [markdown]
# ### 2 MPI - ordered

# %%
fig = plt.figure(figsize=(10, 8))  # Set figure size (width=10, height=8)
ax = fig.add_subplot(111)  # Create the main plot in the entire figure

ax.plot(n_threads, THIN_ord_2_means_ksize_100, label = 'k = 100', color = 'red')
ax.plot(n_threads, THIN_ord_2_means_ksize_500, label = 'k = 500', color = 'green')
ax.plot(n_threads, THIN_ord_2_means_ksize_1000, label = 'k = 1000', color = 'blue')

ax.fill_between(n_threads, THIN_ord_2_means_ksize_1000 - THIN_ord_2_std_ksize_1000, THIN_ord_2_means_ksize_1000 - THIN_ord_2_std_ksize_1000, alpha=0.2, color = 'blue')
ax.fill_between(n_threads, THIN_ord_2_means_ksize_500 - THIN_ord_2_std_ksize_500,  THIN_ord_2_means_ksize_500 + THIN_ord_2_std_ksize_500, alpha=0.2, color = 'green')
ax.fill_between(n_threads, THIN_ord_2_means_ksize_1000 - THIN_ord_2_std_ksize_1000, THIN_ord_2_means_ksize_1000 - THIN_ord_2_std_ksize_1000, alpha=0.2, color = 'blue')



ax.set_xlabel('Number of Threads', fontsize = 16)
ax.set_ylabel('Time', fontsize = 16)
ax.set_title('OpenMP scalability, Ordered, 2 MPI task ', fontsize = 18)

ax.legend(loc='best')

ax.grid()

# %% [markdown]
# ### Speedup 1 MPI task - Serial

# %%
# speedup

#static

speed_stat_1_k_100 = THIN_static_1_means_ksize_100[0]/THIN_static_1_means_ksize_100
speed_stat_1_k_500 = THIN_static_1_means_ksize_500[0]/THIN_static_1_means_ksize_500
speed_stat_1_k_1000 = THIN_static_1_means_ksize_1000[0]/THIN_static_1_means_ksize_1000
speed_stat_1_k_5000 = THIN_static_1_means_ksize_5000[0]/THIN_static_1_means_ksize_5000
speed_stat_1_k_10000 = THIN_static_1_means_ksize_10000[0]/THIN_static_1_means_ksize_10000

speed_stat_2_k_100 = THIN_static_2_means_ksize_100[0]/THIN_static_2_means_ksize_100
speed_stat_2_k_500 = THIN_static_2_means_ksize_500[0]/THIN_static_2_means_ksize_500
speed_stat_2_k_1000 = THIN_static_2_means_ksize_1000[0]/THIN_static_2_means_ksize_1000
speed_stat_2_k_5000 = THIN_static_2_means_ksize_5000[0]/THIN_static_2_means_ksize_5000
speed_stat_2_k_10000 = THIN_static_2_means_ksize_10000[0]/THIN_static_2_means_ksize_10000





#ordered

speed_ord_1_k_100 = THIN_ord_1_means_ksize_100[0]/THIN_ord_1_means_ksize_100
speed_ord_1_k_500 = THIN_ord_1_means_ksize_500[0]/THIN_ord_1_means_ksize_500
speed_ord_1_k_1000 = THIN_ord_1_means_ksize_1000[0]/THIN_ord_1_means_ksize_1000
speed_ord_1_k_5000 = THIN_ord_1_means_ksize_5000[0]/THIN_ord_1_means_ksize_5000
speed_ord_1_k_10000 = THIN_ord_1_means_ksize_10000[0]/THIN_ord_1_means_ksize_10000

# %%
THIN_static_1_means_ksize_10000[0]/THIN_static_1_means_ksize_10000
# Out:
# array([ 1.        ,  1.99380604,  3.96308621,  5.90138777,  7.82342769,
#         9.72019512, 11.57542551])

# %%
speed_stat_1_k_10000
# Out:
# array([1.        , 0.99998153, 0.99999662, 0.99903526, 0.99910593,
#        0.99910322, 0.99908975])

# %%
plt.figure(figsize=(10, 6))

plt.plot(n_threads, speed_stat_1_k_100, label = 'k = 100')
plt.plot(n_threads, speed_stat_1_k_500, label = 'k = 500')
plt.plot(n_threads, speed_stat_1_k_1000, label = 'k = 1000')
plt.plot(n_threads, speed_stat_1_k_5000, label = 'k = 5000')
plt.plot(n_threads, speed_stat_1_k_10000, label = 'k = 10000')

x_values = np.arange(1, 13, 1)
plt.plot(x_values, x_values, c = "gray", linestyle="dashed", label="Theoretical Peak Performance")


plt.xlabel('Number of Threads', fontsize = 16)
plt.ylabel('Speedup', fontsize = 16)
plt.title('Speedup OpenMP scalability - Static evolution, 1 MPI task', fontsize = 18)

plt.legend()

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlim([0,12.5])

plt.grid(linewidth = 0.3)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(n_threads, speed_stat_2_k_100, label = 'k = 100')
plt.plot(n_threads, speed_stat_2_k_500, label = 'k = 500')
plt.plot(n_threads, speed_stat_2_k_1000, label = 'k = 1000')
plt.plot(n_threads, speed_stat_2_k_5000, label = 'k = 5000')
plt.plot(n_threads, speed_stat_2_k_10000, label = 'k = 10000')

x_values = np.arange(1, 13, 1)
plt.plot(x_values, x_values, c = "gray", linestyle="dashed", label="Theoretical Peak Performance")


plt.xlabel('Number of Threads', fontsize = 16)
plt.ylabel('Speedup', fontsize = 16)
plt.title('Speedup OpenMP scalability - Static evolution, 2 MPI task', fontsize = 18)

plt.legend()

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlim([0,12.5])

plt.grid(linewidth = 0.3)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(n_threads, speed_ord_1_k_100, label = 'k = 100')
plt.plot(n_threads, speed_ord_1_k_500, label = 'k = 500')
plt.plot(n_threads, speed_ord_1_k_1000, label = 'k = 1000')
plt.plot(n_threads, speed_ord_1_k_5000, label = 'k = 5000')
plt.plot(n_threads, speed_ord_1_k_10000, label = 'k = 10000')


plt.xlabel('Number of Threads', fontsize = 16)
plt.ylabel('Speedup', fontsize = 16)
plt.title('Speedup OpenMP scalability - Ordered evolution, 1 MPI task', fontsize = 18)

plt.legend()

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlim([0,12.5])

plt.grid(linewidth = 0.3)
plt.show()
